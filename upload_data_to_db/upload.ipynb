# %%
from pymongo.mongo_client import MongoClient
import pandas as pd
import json

uri = "mongodb+srv://yashsharma09147:Yashsharma09147@cluster0.14rzklv.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri)

DATABASE_NAME="pwskills"
COLLECTION_NAME="waferfault"

df = pd.read_csv(r"C:\Users\Yash\pwskill\ML_project\sensor-fault-detection\notebooks\wafer_23012020_041211.csv")
json_record= list(json.loads(df.T.to_json()).values())

#dumb data in database
client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# c:\Users\Yash\pwskill\ML_project\sensor-fault-detection\upload_data_to_db\db.ipynb Cell 1 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Yash/pwskill/ML_project/sensor-fault-detection/upload_data_to_db/db.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> json_record= list(json.loads(df.T.to_json()).values())
#      <a href='vscode-notebook-cell:/c%3A/Users/Yash/pwskill/ML_project/sensor-fault-detection/upload_data_to_db/db.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> #dumb data in database
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Yash/pwskill/ML_project/sensor-fault-detection/upload_data_to_db/db.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
#      <a href='vscode-notebook-cell:/c%3A/Users/Yash/pwskill/ML_project/sensor-fault-detection/upload_data_to_db/db.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a> # Send a ping to confirm a successful connection
#      <a href='vscode-notebook-cell:/c%3A/Users/Yash/pwskill/ML_project/sensor-fault-detection/upload_data_to_db/db.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a> try:
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\collection.py:707, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     705 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     706 blk.ops = [doc for doc in gen()]
# --> 707 blk.execute(write_concern, session=session)
#     708 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\bulk.py:513, in _Bulk.execute(self, write_concern, session)
#     511         self.execute_no_results(sock_info, generator, write_concern)
#     512 else:
# --> 513     return self.execute_command(generator, write_concern, session)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\bulk.py:391, in _Bulk.execute_command(self, generator, write_concern, session)
#     389 client = self.collection.database.client
#     390 with client._tmp_session(session) as s:
# --> 391     client._retry_with_session(self.is_retryable, retryable_bulk, s, self)
#     393 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     394     _raise_bulk_write_error(full_result)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\mongo_client.py:1321, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1311 """Execute an operation with at most one consecutive retries
#    1312
#    1313 Returns func()'s return value on success. On error retries the same
#    (...)
#    1316 Re-raises any exception thrown by func().
#    1317 """
#    1318 retryable = (
#    1319     retryable and self.options.retry_writes and session and not session.in_transaction
#    1320 )
# -> 1321 return self._retry_internal(retryable, func, session, bulk)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\mongo_client.py:1353, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1349 server = self._select_server(writable_server_selector, session)
#    1350 supports_session = (
#    1351     session is not None and server.description.retryable_writes_supported
#    1352 )
# -> 1353 with self._get_socket(server, session) as sock_info:
#    1354     max_wire_version = sock_info.max_wire_version
#    1355     if retryable and not supports_session:
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\mongo_client.py:1189, in MongoClient._get_socket(self, server, session)
#    1187     yield session._pinned_connection
#    1188     return
# -> 1189 with server.get_socket(handler=err_handler) as sock_info:
#    1190     # Pin this session to the selected server or connection.
#    1191     if in_txn and server.description.server_type in (
#    1192         SERVER_TYPE.Mongos,
#    1193         SERVER_TYPE.LoadBalancer,
#    1194     ):
#    1195         session._pin(server, sock_info)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\pool.py:1406, in Pool.get_socket(self, handler)
#    1403 if self.enabled_for_cmap:
#    1404     listeners.publish_connection_check_out_started(self.address)
# -> 1406 sock_info = self._get_socket(handler=handler)
#    1408 if self.enabled_for_cmap:
#    1409     listeners.publish_connection_checked_out(self.address, sock_info.id)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\pool.py:1519, in Pool._get_socket(self, handler)
#    1517 else:  # We need to create a new connection
#    1518     try:
# -> 1519         sock_info = self.connect(handler=handler)
#    1520     finally:
#    1521         with self._max_connecting_cond:
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\pool.py:1377, in Pool.connect(self, handler)
#    1374     if handler:
#    1375         handler.contribute_socket(sock_info, completed_handshake=False)
# -> 1377     sock_info.authenticate()
#    1378 except BaseException:
#    1379     sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\pool.py:869, in SocketInfo.authenticate(self)
#     867 creds = self.opts._credentials
#     868 if creds:
# --> 869     auth.authenticate(creds, self)
#     870 self.ready = True
#     871 if self.enabled_for_cmap:
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\auth.py:549, in authenticate(credentials, sock_info)
#     547 mechanism = credentials.mechanism
#     548 auth_func = _AUTH_MAP[mechanism]
# --> 549 auth_func(credentials, sock_info)
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\auth.py:475, in _authenticate_default(credentials, sock_info)
#     473         return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-256")
#     474     else:
# --> 475         return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-1")
#     476 else:
#     477     return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-1")
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\auth.py:241, in _authenticate_scram(credentials, sock_info, mechanism)
#     232 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     234 cmd = SON(
#     235     [
#     236         ("saslContinue", 1),
#    (...)
#     239     ]
#     240 )
# --> 241 res = sock_info.command(source, cmd)
#     243 parsed = _parse_scram_response(res["payload"])
#     244 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\pool.py:766, in SocketInfo.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     764     self._raise_if_not_writable(unacknowledged)
#     765 try:
# --> 766     return command(
#     767         self,
#     768         dbname,
#     769         spec,
#     770         self.is_mongos,
#     771         read_preference,
#     772         codec_options,
#     773         session,
#     774         client,
#     775         check,
#     776         allowable_errors,
#     777         self.address,
#     778         listeners,
#     779         self.max_bson_size,
#     780         read_concern,
#     781         parse_write_concern_error=parse_write_concern_error,
#     782         collation=collation,
#     783         compression_ctx=self.compression_context,
#     784         use_op_msg=self.op_msg_enabled,
#     785         unacknowledged=unacknowledged,
#     786         user_fields=user_fields,
#     787         exhaust_allowed=exhaust_allowed,
#     788         write_concern=write_concern,
#     789     )
#     790 except (OperationFailure, NotPrimaryError):
#     791     raise
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\network.py:166, in command(sock_info, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     164             client._process_response(response_doc, session)
#     165         if check:
# --> 166             helpers._check_command_response(
#     167                 response_doc,
#     168                 sock_info.max_wire_version,
#     169                 allowable_errors,
#     170                 parse_write_concern_error=parse_write_concern_error,
#     171             )
#     172 except Exception as exc:
#     173     if publish:
#
# File c:\Users\Yash\pwskill\ML_project\sensor_project\env\lib\site-packages\pymongo\helpers.py:181, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     178 elif code == 43:
#     179     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 181 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}
